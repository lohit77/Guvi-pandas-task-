# %% [markdown]
# <a href="https://colab.research.google.com/github/lohit77/Guvi-pandas-task-/blob/main/lohit_pandas_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas

# %% [markdown]
# ## Importing pandas
#
# ### Getting started and checking your pandas setup
#
# Difficulty: *easy*
#
# **1.** Import pandas under the name `pd`.

# %%
import pandas as pd

# %% [markdown]
# **2.** Print the version of pandas that has been imported.

# %%
pd.__version__
# Out:
# '1.3.5'

# %% [markdown]
# **3.** Print out all the version information of the libraries that are required by the pandas library.

# %%
pd.show_versions
# Out:
# <function pandas.util._print_versions.show_versions(as_json: 'str | bool' = False) -> 'None'>

# %% [markdown]
# ## DataFrame basics
#
# ### A few of the fundamental routines for selecting, sorting, adding and aggregating data in DataFrames
#
# Difficulty: *easy*
#
# Note: remember to import numpy using:
# ```python
# import numpy as np
# ```
#
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
# (This is just some meaningless data I made up with the theme of animals and trips to a vet.)
#
# **4.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
import numpy as np

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df=pd.DataFrame(data,index=labels)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **5.** Display a summary of the basic information about this DataFrame and its data.

# %%
df.info()        #gives the information of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   animal    10 non-null     object
#  1   age       8 non-null      float64
#  2   visits    10 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %%
df.describe()      #it gives the summary of the numerical columns in the dataset
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   3.375000   1.900000
# std    2.065879   0.875595
# min    0.500000   1.000000
# 25%    2.250000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %% [markdown]
# **6.** Return the first 3 rows of the DataFrame `df`.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# **7.** Select just the 'animal' and 'age' columns from the DataFrame `df`.

# %%
df_=pd.DataFrame(df,columns=["animal","age"])
df_
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# **8.** Select the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']`.

# %%
df_
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %%
df_.iloc[[3,4,8]]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# **9.** Select only the rows where the number of visits is greater than 3.

# %%
df.loc[df.visits>3]
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# **10.** Select the rows where the age is missing, i.e. is `NaN`.

# %%
df.loc[df.age.isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# **11.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
df.loc[(df.animal=="cat")&(df.age<3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# **12.** Select the rows the age is between 2 and 4 (inclusive).

# %%
df.loc[(df.age>=2)&(df.age<=4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# **13.** Change the age in row 'f' to 1.5.

# %%
df.loc[df.index=="f",["age"]]=1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# **14.** Calculate the sum of all visits (the total number of visits).

# %%
df["visits"].sum()
# Out:
# 19

# %% [markdown]
# **15.** Calculate the mean age for each different animal in `df`.

# %%
df.groupby("animal")["age"].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# **16.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %%
df1 = pd.DataFrame([["cat",4.5,3,"yes"]], columns = ["animal",'age', 'visits','priority'], index = ['k'])

# %%
df=df.append(df1)
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# f    cat  4.5       3      yes
# k    cat  4.5       3      yes

# %%
df = df.drop('k')

# %%
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# f    cat  4.5       3      yes

# %% [markdown]
# **17.** Count the number of each type of animal in `df`.

# %%
df.value_counts()
# Out:
# animal  age  visits  priority
# cat     2.0  3       no          1
#         2.5  1       yes         1
#         3.0  3       yes         1
#         4.5  3       yes         1
# dog     3.0  1       no          1
#         5.0  2       no          1
#         7.0  2       no          1
# snake   0.5  2       no          1
#         4.5  1       no          1
# dtype: int64

# %%
df.groupby(['animal']).size()
# Out:
# animal
# cat      4
# dog      4
# snake    2
# dtype: int64

# %% [markdown]
# **18.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visit' column in *ascending* order.

# %%
df.sort_values(by=['age'], ascending=[False])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# f    cat  4.5       3      yes
# b    cat  3.0       3      yes
# j    dog  3.0       1       no
# a    cat  2.5       1      yes
# f    cat  2.0       3       no
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %%
df.sort_values(by=['visits'], ascending=[True])
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# j    dog  3.0       1       no
# c  snake  0.5       2       no
# e    dog  5.0       2       no
# i    dog  7.0       2       no
# b    cat  3.0       3      yes
# d    dog  NaN       3      yes
# f    cat  2.0       3       no
# f    cat  4.5       3      yes

# %%
df.sort_values(by=['age','visits'] ,ascending=[False,True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# f    cat  4.5       3      yes
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  2.0       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# **19.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
df['priority'] = df['priority'].map({'yes':True ,'no':False})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  2.0       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False
# f    cat  4.5       3      True

# %% [markdown]
# **20.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df3 = df.replace({'animal': {'snake': "python"}})

# %%
df3
# Out:
#    animal  age  visits priority
# a     cat  2.5       1      NaN
# b     cat  3.0       3      NaN
# c  python  0.5       2      NaN
# d     dog  NaN       3      NaN
# e     dog  5.0       2      NaN
# f     cat  2.0       3      NaN
# g  python  4.5       1      NaN
# h     cat  NaN       1      NaN
# i     dog  7.0       2      NaN
# j     dog  3.0       1      NaN
# f     cat  4.5       3      NaN

# %% [markdown]
# **21.** For each animal type and each number of visits, find the mean age. In other words, each row is an animal, each column is a number of visits and the values are the mean ages (hint: use a pivot table).

# %%
pi_tab = pd.pivot_table(df,values=['visits'],index=['animal'], aggfunc=np.mean)

# %%
pi_tab
# Out:
#         visits
# animal
# cat        2.2
# dog        2.0
# python     1.5

# %% [markdown]
# ## DataFrames: beyond the basics
#
# ### Slightly trickier: you may need to combine two or more methods to get the right answer
#
# Difficulty: *medium*
#
# The previous section was tour through some basic but essential DataFrame operations. Below are some ways that you might need to cut your data, but for which there is no single "out of the box" method.

# %% [markdown]
# **22.** You have a DataFrame `df` with a column 'A' of integers. For example:
# ```python
# df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})
# ```
#
# How do you filter out rows which contain the same integer as the row immediately above?

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})
df
# Out:
#     A
# 0   1
# 1   2
# 2   2
# 3   3
# 4   4
# 5   5
# 6   5
# 7   5
# 8   6
# 9   7
# 10  7

# %%
df.loc[df['A'].shift() !=  df['A']]       # '!=' operator is used to check whether the above row is not equal to below row
# Out:
#    A
# 0  1
# 1  2
# 3  3
# 4  4
# 5  5
# 8  6
# 9  7

# %% [markdown]
# **23.** Given a DataFrame of numeric values, say
# ```python
# df = pd.DataFrame(np.random.random(size=(5, 3))) # a 5x3 frame of float values
# ```
#
# how do you subtract the row mean from each element in the row?

# %%
df = pd.DataFrame(np.random.random(size=(5, 3))) 
df
# Out:
#           0         1         2
# 0  0.937995  0.048850  0.570506
# 1  0.497800  0.851237  0.150956
# 2  0.964749  0.799681  0.529342
# 3  0.337534  0.572335  0.597061
# 4  0.387387  0.942696  0.326582

# %%
df.sub(df.mean(axis=1), axis=0)              #axis =1 takes the elements in the row and axis =0 takes the values in the columns
# Out:
#           0         1         2
# 0  0.261991 -0.327041  0.065050
# 1  0.124705 -0.281492  0.156787
# 2 -0.106968 -0.029020  0.135988
# 3  0.035368  0.187481 -0.222849
# 4  0.104974 -0.230329  0.125355

# %% [markdown]
# **24.** Suppose you have DataFrame with 10 columns of real numbers, for example:
#
# ```python
# df = pd.DataFrame(np.random.random(size=(5, 10)), columns=list('abcdefghij'))
# ```
# Which column of numbers has the smallest sum? (Find that column's label.)

# %%
df = pd.DataFrame(np.random.random(size=(5, 10)), columns=list('abcdefghij'))
df
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.740421  0.331988  0.637442  0.064437  0.358497  0.528967  0.381136
# 1  0.852401  0.353333  0.834830  0.352982  0.332585  0.341798  0.676677
# 2  0.827857  0.618706  0.718698  0.390885  0.268476  0.431584  0.733458
# 3  0.138043  0.743860  0.579741  0.221151  0.322202  0.671615  0.910002
# 4  0.310796  0.198181  0.818385  0.166475  0.660119  0.497840  0.013035
#
#           h         i         j
# 0  0.605276  0.686814  0.386623
# 1  0.015507  0.396955  0.740464
# 2  0.973215  0.191599  0.120325
# 3  0.934444  0.402677  0.434052
# 4  0.388607  0.298404  0.412656

# %%
df.sum().idxmin()     # here df.sum gives the sum of the columns and idxmin() method returns a Series with the index of the smallest value for each column
# Out:
# 'd'

# %% [markdown]
# **25.** How do you count how many unique rows a DataFrame has (i.e. ignore all rows that are duplicates)?

# %%
len(df.nunique(axis=1))      # nunique gives the unique rows(axis=1) in a dataframe
# Out:
# 5

# %% [markdown]
# The next three puzzles are slightly harder...
#
# **26.** You have a DataFrame that consists of 10 columns of floating--point numbers. Suppose that exactly 5 entries in each row are NaN values. For each row of the DataFrame, find the *column* which contains the *third* NaN value.
#
# (You should return a Series of column labels.)

# %% [markdown]
# **27.** A DataFrame has a column of groups 'grps' and and column of numbers 'vals'. For example:
#
# ```python
# df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'),
#                    'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})
# ```
# For each *group*, find the sum of the three greatest values.

# %%
df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'), 
                   'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})
df
# Out:
#    grps  vals
# 0     a    12
# 1     a   345
# 2     a     3
# 3     b     1
# 4     b    45
# 5     c    14
# 6     a     4
# 7     a    52
# 8     b    54
# 9     c    23
# 10    c   235
# 11    c    21
# 12    b    57
# 13    b     3
# 14    c    87

# %%
df.groupby(['grps']).vals.nlargest(3)     #here we are grouping all the values (a,b,c) and we take the largest values in each of the three
# Out:
# grps
# a     1     345
#       7      52
#       0      12
# b     12     57
#       8      54
#       4      45
# c     10    235
#       14     87
#       9      23
# Name: vals, dtype: int64

# %%
df.groupby(['grps']).vals.nlargest(3).sum(level=0)    #here after taking the largest values in each group we sum them
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   """Entry point for launching an IPython kernel.
# grps
# a    409
# b    156
# c    345
# Name: vals, dtype: int64

# %% [markdown]
# **28.** A DataFrame has two integer columns 'A' and 'B'. The values in 'A' are between 1 and 100 (inclusive). For each group of 10 consecutive integers in 'A' (i.e. `(0, 10]`, `(10, 20]`, ...), calculate the sum of the corresponding values in column 'B'.

# %% [markdown]
# ## DataFrames: harder problems
#
# ### These might require a bit of thinking outside the box...
#
# ...but all are solvable using just the usual pandas/NumPy methods (and so avoid using explicit `for` loops).
#
# Difficulty: *hard*

# %% [markdown]
# **29.** Consider a DataFrame `df` where there is an integer column 'X':
# ```python
# df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})
# ```
# For each value, count the difference back to the previous zero (or the start of the Series, whichever is closer). These values should therefore be `[1, 2, 0, 1, 2, 3, 4, 0, 1, 2]`. Make this a new column 'Y'.

# %%
df = pd.DataFrame({'X': [7, 2, 0, 3, 4, 2, 5, 0, 3, 4]})

# %% [markdown]
# Here's an alternative approach based on a [cookbook recipe](http://pandas.pydata.org/pandas-docs/stable/cookbook.html#grouping):

# %% [markdown]
# **30.** Consider a DataFrame containing rows and columns of purely numerical data. Create a list of the row-column index locations of the 3 largest values.

# %% [markdown]
# **31.** Given a DataFrame with a column of group IDs, 'grps', and a column of corresponding integer values, 'vals', replace any negative values in 'vals' with the group mean.

# %% [markdown]
# **32.** Implement a rolling mean over groups with window size 3, which ignores NaN value. For example consider the following DataFrame:
#
# ```python
# >>> df = pd.DataFrame({'group': list('aabbabbbabab'),
#                        'value': [1, 2, 3, np.nan, 2, 3,
#                                  np.nan, 1, 7, 3, np.nan, 8]})
# >>> df
#    group  value
# 0      a    1.0
# 1      a    2.0
# 2      b    3.0
# 3      b    NaN
# 4      a    2.0
# 5      b    3.0
# 6      b    NaN
# 7      b    1.0
# 8      a    7.0
# 9      b    3.0
# 10     a    NaN
# 11     b    8.0
# ```
# The goal is to compute the Series:
#
# ```
# 0     1.000000
# 1     1.500000
# 2     3.000000
# 3     3.000000
# 4     1.666667
# 5     3.000000
# 6     3.000000
# 7     2.000000
# 8     3.666667
# 9     2.000000
# 10    4.500000
# 11    4.000000
# ```
# E.g. the first window of size three for group 'b' has values 3.0, NaN and 3.0 and occurs at row index 5. Instead of being NaN the value in the new column at this row index should be 3.0 (just the two non-NaN values are used to compute the mean (3+3)/2)

# %% [markdown]
# ## Series and DatetimeIndex
#
# ### Exercises for creating and manipulating Series with datetime data
#
# Difficulty: *easy/medium*
#
# pandas is fantastic for working with dates and times. These puzzles explore some of this functionality.

# %% [markdown]
# **33.** Create a DatetimeIndex that contains each business day of 2015 and use it to index a Series of random numbers. Let's call this Series `s`.

# %%
Date = pd.date_range(start='2015-01-01' , end='2015-12-31' , freq="B" ) #here taking the daterange from 1st of jan 2015 to 31st of dec 2015 the complete year and the freq as business days('B')
s=pd.Series(np.random.rand(Date.shape[0]),index=Date)     #here taking a random series and assigning it to each day and shape[0] mentions the rows in the data frame

# %%
s
# Out:
# 2015-01-01    0.775478
# 2015-01-02    0.326661
# 2015-01-05    0.263832
# 2015-01-06    0.649543
# 2015-01-07    0.897267
#                 ...
# 2015-12-25    0.985861
# 2015-12-28    0.311638
# 2015-12-29    0.766575
# 2015-12-30    0.592985
# 2015-12-31    0.112116
# Freq: B, Length: 261, dtype: float64

# %% [markdown]
# **34.** Find the sum of the values in `s` for every Wednesday.

# %%
s[s.index.dayofweek == 2].sum()        #as we know the index of monday is 0 and so the index of wednesday would be 2  and taking (dayofweek) and adding all the values of wednesday .
# Out:
# 26.93467837922293

# %%
round(s[s.index.dayofweek == 2].sum(),2)      #rounding of the decimal by two values
# Out:
# 26.93

# %% [markdown]
# **35.** For each calendar month in `s`, find the mean of values.

# %%
Months_Mean = s.groupby(s.index.month).mean()    #here using groupby method on s and calculating mean for every month
Month_list= ['Jan-15', 'Feb-15', 'Mar-15', 'Apr-15', 'May-15', 'Jun-15', 'Jul-15', 'Aug-15', 'Sep-15', 'Oct-15','Nov-15', 'Dec-15'] #creating list of months in the year 2015 to make them the indexs for the mean values 
Months_Mean.index=Month_list      #now indexing the mean with the month list

# %%
Months_Mean        #printing the mean
# Out:
# Jan-15    0.572590
# Feb-15    0.339152
# Mar-15    0.523507
# Apr-15    0.412931
# May-15    0.521085
# Jun-15    0.391334
# Jul-15    0.548434
# Aug-15    0.430756
# Sep-15    0.527733
# Oct-15    0.528501
# Nov-15    0.528914
# Dec-15    0.544758
# dtype: float64

# %% [markdown]
# **36.** For each group of four consecutive calendar months in `s`, find the date on which the highest value occurred.

# %%
Four_Consec_Months = [Month_list[i] + "-" + Month_list[i + 3] for i in range(9)]   #Range is used as (1,10) since there are 9 such groups and taking it for every four groups.

# %%
Max_date_val = [(s[(s.index.month >= i) & (s.index.month <= (i+3))]).idxmax() for i in range(9)]

# %%
Max_date_series = pd.Series(Max_date_val, index = Four_Consec_Months)   #Creating a series using the dates with maximum value indexed with 'Four_Consec_Months'(four consecutive months) list.
print("Highest value occurred in the series s for the year 2015 : " )
Max_date_series                                                         #printing the highest values for random series in the year 2015
# Out:
# Highest value occurred in the series s for the year 2015 :
# Jan-15-Apr-15   2015-03-17
# Feb-15-May-15   2015-03-17
# Mar-15-Jun-15   2015-03-17
# Apr-15-Jul-15   2015-03-17
# May-15-Aug-15   2015-05-15
# Jun-15-Sep-15   2015-05-15
# Jul-15-Oct-15   2015-09-03
# Aug-15-Nov-15   2015-10-12
# Sep-15-Dec-15   2015-10-12
# dtype: datetime64[ns]

# %% [markdown]
# **37.** Create a DateTimeIndex consisting of the third Thursday in each month for the years 2015 and 2016.

# %%
pd.date_range('2015-01-01', '2016-12-31', freq='WOM-3THU')       #here "WOM means WEEK OF MONTH" so the freq refers to every 3rd thursday in every month
# Out:
# DatetimeIndex(['2015-01-15', '2015-02-19', '2015-03-19', '2015-04-16',
#                '2015-05-21', '2015-06-18', '2015-07-16', '2015-08-20',
#                '2015-09-17', '2015-10-15', '2015-11-19', '2015-12-17',
#                '2016-01-21', '2016-02-18', '2016-03-17', '2016-04-21',
#                '2016-05-19', '2016-06-16', '2016-07-21', '2016-08-18',
#                '2016-09-15', '2016-10-20', '2016-11-17', '2016-12-15'],
#               dtype='datetime64[ns]', freq='WOM-3THU')

# %% [markdown]
# ## Cleaning Data
#
# ### Making a DataFrame easier to work with
#
# Difficulty: *easy/medium*
#
# It happens all the time: someone gives you data containing malformed strings, Python, lists and missing data. How do you tidy it up so you can get on with the analysis?
#
# Take this monstrosity as the DataFrame to use in the following puzzles:
#
# ```python
# df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm',
#                                'Budapest_PaRis', 'Brussels_londOn'],
#               'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
#               'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
#                    'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
#                                '12. Air France', '"Swiss Air"']})
# ```
# (It's some flight data I made up; it's not meant to be accurate in any way.)

# %% [markdown]
# **38.** Some values in the the FlightNumber column are missing. These numbers are meant to increase by 10 with each row so 10055 and 10075 need to be put in place. Fill in these missing numbers and make the column an integer column (instead of a float column).

# %%
import pandas as pd 
import numpy as np


df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN', 'londON_StockhOlm', 
                               'Budapest_PaRis', 'Brussels_londOn'],
              'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
              'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
                   'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
                               '12. Air France', '"Swiss Air"']})

df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df['FlightNumber']
# Out:
# 0    10045.0
# 1        NaN
# 2    10065.0
# 3        NaN
# 4    10085.0
# Name: FlightNumber, dtype: float64

# %%
NewIndex=np.arange(1,df.From_To.count()+1)      #creating a new index 
NewIndex
df.set_index(NewIndex , inplace=True)           #setting the index using set_index and inplace=true so that it returns the same dataframe with updated index
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 1      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 2      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 3  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_PaRis       10075.0          [13]       12. Air France
# 5   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
for i in np.arange(1,df.From_To.count()+1):                      #taking for loop for the dataframe  
  if pd.isnull(df.FlightNumber.loc[i,]):                         #giving if condition and checking for every row that has null values using isnull function and verifying every row by loc function
    df.loc[i,'FlightNumber']=df.FlightNumber.loc[i-1,]+10        #now locating for every row(i) and "FlightNumber" column and adding  10 to the previous value
df["FlightNumber"]
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 1      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 2      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 3  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_PaRis       10075.0          [13]       12. Air France
# 5   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df["FlightNumber"].astype(int)       #converting the values of the column FlightNumber into integer
# Out:
# 1    10045
# 2    10055
# 3    10065
# 4    10075
# 5    10085
# Name: FlightNumber, dtype: int64

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 1      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 2      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 3  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_PaRis       10075.0          [13]       12. Air France
# 5   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %% [markdown]
# **39.** The From\_To column would be better as two separate columns! Split each string on the underscore delimiter `_` to give a new temporary DataFrame with the correct values. Assign the correct column names to this temporary DataFrame.

# %%
 df['From_To']
# Out:
# 1        LoNDon_paris
# 2        MAdrid_miLAN
# 3    londON_StockhOlm
# 4      Budapest_PaRis
# 5     Brussels_londOn
# Name: From_To, dtype: object

# %%
DF1 = df.copy()                                                      #creating a temporary dataframe(DF1)
DF1[['From','To']]=DF1.From_To.str.split("_",expand=True)            #here spliting the string into two parts by using str.split and expand=true splits into two columns 
DF1                                                                  #printing the new df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 1      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 2      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 3  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_PaRis       10075.0          [13]       12. Air France
# 5   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 1    LoNDon      paris
# 2    MAdrid      miLAN
# 3    londON  StockhOlm
# 4  Budapest      PaRis
# 5  Brussels     londOn

# %% [markdown]
# **40.** Notice how the capitalisation of the city names is all mixed up in this temporary DataFrame. Standardise the strings so that only the first letter is uppercase (e.g. "londON" should become "London".)

# %%
DF1.From_To=DF1.From_To.str.capitalize()          #capitalising the strings in "From_To" column using capitalize() function 
DF1
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 1      London_paris       10045.0      [23, 47]               KLM(!)
# 2      Madrid_milan       10055.0            []    <Air France> (12)
# 3  London_stockholm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_paris       10075.0          [13]       12. Air France
# 5   Brussels_london       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 1    LoNDon      paris
# 2    MAdrid      miLAN
# 3    londON  StockhOlm
# 4  Budapest      PaRis
# 5  Brussels     londOn

# %%
DF1.From=DF1.From.str.capitalize()          #capitalising the strings in "From" column using capitalize() function 
DF1
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 1      London_paris       10045.0      [23, 47]               KLM(!)
# 2      Madrid_milan       10055.0            []    <Air France> (12)
# 3  London_stockholm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_paris       10075.0          [13]       12. Air France
# 5   Brussels_london       10085.0      [67, 32]          "Swiss Air"
#
#        From         To
# 1    London      paris
# 2    Madrid      miLAN
# 3    London  StockhOlm
# 4  Budapest      PaRis
# 5  Brussels     londOn

# %%
DF1.To=DF1.To.str.capitalize()          #capitalising the strings in "To" column using capitalize() function 
DF1

# %% [markdown]
# **41.** Delete the From_To column from `df` and attach the temporary DataFrame from the previous questions.

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 1      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 2      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 3  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 4    Budapest_PaRis       10075.0          [13]       12. Air France
# 5   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df.drop('From_To',axis=1,inplace=True)     #deleting From_To column from df 
df
# Out:
#    FlightNumber  RecentDelays              Airline
# 1       10045.0      [23, 47]               KLM(!)
# 2       10055.0            []    <Air France> (12)
# 3       10065.0  [24, 43, 87]  (British Airways. )
# 4       10075.0          [13]       12. Air France
# 5       10085.0      [67, 32]          "Swiss Air"

# %%
df["From_To"]=DF1["From_To"]                   #adding the "From_To" column from DF1  to df
df
# Out:
#    FlightNumber  RecentDelays              Airline           From_To
# 1       10045.0      [23, 47]               KLM(!)      London_paris
# 2       10055.0            []    <Air France> (12)      Madrid_milan
# 3       10065.0  [24, 43, 87]  (British Airways. )  London_stockholm
# 4       10075.0          [13]       12. Air France    Budapest_paris
# 5       10085.0      [67, 32]          "Swiss Air"   Brussels_london

# %% [markdown]
# **42**. In the Airline column, you can see some extra puctuation and symbols have appeared around the airline names. Pull out just the airline name. E.g. `'(British Airways. )'` should become `'British Airways'`.

# %%
df.Airline=df.Airline.str.replace(r"[^a-zA-z]",'')       #replacing the extra special characters and  giving the condition that the string should start with a-zA-z
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.
#    FlightNumber  RecentDelays         Airline           From_To
# 1       10045.0      [23, 47]             KLM      London_paris
# 2       10055.0            []       AirFrance      Madrid_milan
# 3       10065.0  [24, 43, 87]  BritishAirways  London_stockholm
# 4       10075.0          [13]       AirFrance    Budapest_paris
# 5       10085.0      [67, 32]        SwissAir   Brussels_london

# %% [markdown]
# **43**. In the RecentDelays column, the values have been entered into the DataFrame as a list. We would like each first value in its own column, each second value in its own column, and so on. If there isn't an Nth value, the value should be NaN.
#
# Expand the Series of lists into a DataFrame named `delays`, rename the columns `delay_1`, `delay_2`, etc. and replace the unwanted RecentDelays column in `df` with `delays`.

# %%
df_delays=pd.DataFrame(df["RecentDelays"].values.tolist())
df_delays.columns = ['delay_{}'.format(n) for n in range(1, len(df_delays.columns)+1)]
df_delays
# Out:
#    delay_1  delay_2  delay_3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
df=df.drop("RecentDelays" , axis=1).join(df_delays)
print("The Data of airlines and there delays : ")
df
# Out:
# The Data of airlines and there delays :
#             From_To  FlightNumber              Airline  delay_1  delay_2  \
# 0      LoNDon_paris       10045.0               KLM(!)     23.0     47.0
# 1      MAdrid_miLAN           NaN    <Air France> (12)      NaN      NaN
# 2  londON_StockhOlm       10065.0  (British Airways. )     24.0     43.0
# 3    Budapest_PaRis           NaN       12. Air France     13.0      NaN
# 4   Brussels_londOn       10085.0          "Swiss Air"     67.0     32.0
#
#    delay_3
# 0      NaN
# 1      NaN
# 2     87.0
# 3      NaN
# 4      NaN

# %% [markdown]
# The DataFrame should look much better now.

# %% [markdown]
# ## Using MultiIndexes
#
# ### Go beyond flat DataFrames with additional index levels
#
# Difficulty: *medium*
#
# Previous exercises have seen us analysing data from DataFrames equipped with a single index level. However, pandas also gives you the possibilty of indexing your data using *multiple* levels. This is very much like adding new dimensions to a Series or a DataFrame. For example, a Series is 1D, but by using a MultiIndex with 2 levels we gain of much the same functionality as a 2D DataFrame.
#
# The set of puzzles below explores how you might use multiple index levels to enhance data analysis.
#
# To warm up, we'll look make a Series with two index levels.

# %% [markdown]
# **44**. Given the lists `letters = ['A', 'B', 'C']` and `numbers = list(range(10))`, construct a MultiIndex object from the product of the two lists. Use it to index a Series of random numbers. Call this Series `s`.

# %%
import pandas as pd 
import numpy as np


letters = ['A', 'B', 'C']
numbers = list(range(10))

MI = pd.MultiIndex.from_product([letters, numbers])            #constructing a multiindex(MI) using multiindex.from_product
S = pd.Series(np.random.rand(30), index=MI)                    #creating a random series S and indexing it with MI

# %%
S                                                              #printing the series S
# Out:
# A  0    0.732359
#    1    0.744461
#    2    0.374053
#    3    0.932322
#    4    0.442266
#    5    0.075103
#    6    0.523855
#    7    0.791458
#    8    0.474122
#    9    0.622384
# B  0    0.920708
#    1    0.850968
#    2    0.865638
#    3    0.786077
#    4    0.223939
#    5    0.142211
#    6    0.585151
#    7    0.470342
#    8    0.647749
#    9    0.802980
# C  0    0.238255
#    1    0.600637
#    2    0.210358
#    3    0.372216
#    4    0.413557
#    5    0.825619
#    6    0.236638
#    7    0.420183
#    8    0.369631
#    9    0.750199
# dtype: float64

# %% [markdown]
# **45.** Check the index of `s` is lexicographically sorted (this is a necessary proprty for indexing to work correctly with a MultiIndex).

# %%
S.index.is_lexsorted()              #Using is_lexsorted() function we check whether the index of S is  lexicographically sorted or not
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: MultiIndex.is_lexsorted is deprecated as a public function, users should use MultiIndex.is_monotonic_increasing instead.
#   """Entry point for launching an IPython kernel.
# True

# %% [markdown]
# **46**. Select the labels `1`, `3` and `6` from the second level of the MultiIndexed Series.

# %%
S.loc[:, [1, 3, 6]]                #selecting [1,3,6] labels using loc function and taking the complete letters(A,B,C) index and slicing for [1,3,6]
# Out:
# A  1    0.744461
#    3    0.932322
#    6    0.523855
# B  1    0.850968
#    3    0.786077
#    6    0.585151
# C  1    0.600637
#    3    0.372216
#    6    0.236638
# dtype: float64

# %% [markdown]
# **47**. Slice the Series `s`; slice up to label 'B' for the first level and from label 5 onwards for the second level.

# %%
S.loc[:'B', 5:]           #Here first slicing till label B in the first level and slicing from 5 till ending in the second label
# Out:
# A  5    0.075103
#    6    0.523855
#    7    0.791458
#    8    0.474122
#    9    0.622384
# B  5    0.142211
#    6    0.585151
#    7    0.470342
#    8    0.647749
#    9    0.802980
# dtype: float64

# %% [markdown]
# **48**. Sum the values in `s` for each label in the first level (you should have Series giving you a total for labels A, B and C).

# %%
S.sum(level=0)    #here s.sum gives the sum and level=0 gives the individual sum of label 1 (A,B,C).
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   """Entry point for launching an IPython kernel.
# A    5.712384
# B    6.295763
# C    4.437292
# dtype: float64

# %% [markdown]
# **49**. Suppose that `sum()` (and other methods) did not accept a `level` keyword argument. How else could you perform the equivalent of `s.sum(level=1)`?

# %%
S.sum(level=1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   """Entry point for launching an IPython kernel.
# 0    1.891322
# 1    2.196065
# 2    1.450049
# 3    2.090615
# 4    1.079762
# 5    1.042933
# 6    1.345644
# 7    1.681983
# 8    1.491502
# 9    2.175563
# dtype: float64

# %%
S.unstack().sum(axis=0)        #instead of using S.sum(level=1) this we can get the same output using unstack method
# Out:
# 0    1.891322
# 1    2.196065
# 2    1.450049
# 3    2.090615
# 4    1.079762
# 5    1.042933
# 6    1.345644
# 7    1.681983
# 8    1.491502
# 9    2.175563
# dtype: float64

# %% [markdown]
# **50**. Exchange the levels of the MultiIndex so we have an index of the form (letters, numbers). Is this new Series properly lexsorted? If not, sort it.

# %%
S1 = S.swaplevel(0, 1)        #exchanging the labels of S and creating a new series 
S1
# Out:
# 0  A    0.732359
# 1  A    0.744461
# 2  A    0.374053
# 3  A    0.932322
# 4  A    0.442266
# 5  A    0.075103
# 6  A    0.523855
# 7  A    0.791458
# 8  A    0.474122
# 9  A    0.622384
# 0  B    0.920708
# 1  B    0.850968
# 2  B    0.865638
# 3  B    0.786077
# 4  B    0.223939
# 5  B    0.142211
# 6  B    0.585151
# 7  B    0.470342
# 8  B    0.647749
# 9  B    0.802980
# 0  C    0.238255
# 1  C    0.600637
# 2  C    0.210358
# 3  C    0.372216
# 4  C    0.413557
# 5  C    0.825619
# 6  C    0.236638
# 7  C    0.420183
# 8  C    0.369631
# 9  C    0.750199
# dtype: float64

# %%
S1.index.is_lexsorted()        #checking whether the new series S1 is lexicographically sorted or not
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: MultiIndex.is_lexsorted is deprecated as a public function, users should use MultiIndex.is_monotonic_increasing instead.
#   """Entry point for launching an IPython kernel.
# False

# %%
S1 = S1.sort_index()        #the series is not lexicographically sorted so sorting it using sort_index 
S1                          #printing the sorted new series S1
# Out:
# 0  A    0.732359
#    B    0.920708
#    C    0.238255
# 1  A    0.744461
#    B    0.850968
#    C    0.600637
# 2  A    0.374053
#    B    0.865638
#    C    0.210358
# 3  A    0.932322
#    B    0.786077
#    C    0.372216
# 4  A    0.442266
#    B    0.223939
#    C    0.413557
# 5  A    0.075103
#    B    0.142211
#    C    0.825619
# 6  A    0.523855
#    B    0.585151
#    C    0.236638
# 7  A    0.791458
#    B    0.470342
#    C    0.420183
# 8  A    0.474122
#    B    0.647749
#    C    0.369631
# 9  A    0.622384
#    B    0.802980
#    C    0.750199
# dtype: float64

# %% [markdown]
# ## Minesweeper
#
# ### Generate the numbers for safe squares in a Minesweeper grid
#
# Difficulty: *medium* to *hard*
#
# If you've ever used an older version of Windows, there's a good chance you've played with [Minesweeper](https://en.wikipedia.org/wiki/Minesweeper_(video_game). If you're not familiar with the game, imagine a grid of squares: some of these squares conceal a mine. If you click on a mine, you lose instantly. If you click on a safe square, you reveal a number telling you how many mines are found in the squares that are immediately adjacent. The aim of the game is to uncover all squares in the grid that do not contain a mine.
#
# In this section, we'll make a DataFrame that contains the necessary data for a game of Minesweeper: coordinates of the squares, whether the square contains a mine and the number of mines found on adjacent squares.

# %% [markdown]
# **51**. Let's suppose we're playing Minesweeper on a 5 by 4 grid, i.e.
# ```
# X = 5
# Y = 4
# ```
# To begin, generate a DataFrame `df` with two columns, `'x'` and `'y'` containing every coordinate for this grid. That is, the DataFrame should start:
# ```
#    x  y
# 0  0  0
# 1  0  1
# 2  0  2
# ```

# %%
import pandas as pd 
import numpy as np

X = 5
Y = 4

p = pd.core.reshape.util.cartesian_product([np.arange(X), np.arange(Y)])
df = pd.DataFrame(np.asarray(p).T, columns=['x', 'y'])
df
# Out:
#     x  y
# 0   0  0
# 1   0  1
# 2   0  2
# 3   0  3
# 4   1  0
# 5   1  1
# 6   1  2
# 7   1  3
# 8   2  0
# 9   2  1
# 10  2  2
# 11  2  3
# 12  3  0
# 13  3  1
# 14  3  2
# 15  3  3
# 16  4  0
# 17  4  1
# 18  4  2
# 19  4  3

# %% [markdown]
# **52**. For this DataFrame `df`, create a new column of zeros (safe) and ones (mine). The probability of a mine occuring at each location should be 0.4.

# %%
df['mine'] = np.random.binomial(1, 0.4, X*Y)        #adding a new column "mine" and giving the probability of the mine as 0.4 using random.binomial
df
# Out:
#     x  y  mine
# 0   0  0     0
# 1   0  1     0
# 2   0  2     0
# 3   0  3     1
# 4   1  0     1
# 5   1  1     1
# 6   1  2     0
# 7   1  3     0
# 8   2  0     0
# 9   2  1     0
# 10  2  2     1
# 11  2  3     0
# 12  3  0     0
# 13  3  1     0
# 14  3  2     1
# 15  3  3     0
# 16  4  0     0
# 17  4  1     0
# 18  4  2     0
# 19  4  3     1

# %% [markdown]
# **53**. Now create a new column for this DataFrame called `'adjacent'`. This column should contain the number of mines found on adjacent squares in the grid.
#
# (E.g. for the first row, which is the entry for the coordinate `(0, 0)`, count how many mines are found on the coordinates `(0, 1)`, `(1, 0)` and `(1, 1)`.)

# %% [markdown]
# **54**. For rows of the DataFrame that contain a mine, set the value in the `'adjacent'` column to NaN.

# %% [markdown]
# **55**. Finally, convert the DataFrame to grid of the adjacent mine counts: columns are the `x` coordinate, rows are the `y` coordinate.

# %% [markdown]
# ## Plotting
#
# ### Visualize trends and patterns in data
#
# Difficulty: *medium*
#
# To really get a good understanding of the data contained in your DataFrame, it is often essential to create plots: if you're lucky, trends and anomalies will jump right out at you. This functionality is baked into pandas and the puzzles below explore some of what's possible with the library.
#
# **56.** Pandas is highly integrated with the plotting library matplotlib, and makes plotting DataFrames very user-friendly! Plotting in a notebook environment usually makes use of the following boilerplate:
#
# ```python
# import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('ggplot')
# ```
#
# matplotlib is the plotting library which pandas' plotting functionality is built upon, and it is usually aliased to ```plt```.
#
# ```%matplotlib inline``` tells the notebook to show plots inline, instead of creating them in a separate window.
#
# ```plt.style.use('ggplot')``` is a style theme that most people find agreeable, based upon the styling of R's ggplot package.
#
# For starters, make a scatter plot of this random data, but use black X's instead of the default markers.
#
# ```df = pd.DataFrame({"xs":[1,5,2,8,1], "ys":[4,2,1,9,6]})```
#
# Consult the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html) if you get stuck!

# %%
import matplotlib.pyplot as plt                 #importing libraries
# %matplotlib inline
plt.style.use('ggplot')

df = pd.DataFrame({"xs":[1,5,2,8,1], "ys":[4,2,1,9,6]})        #creating a dataframe with "xs","ys".
df.plot.scatter("xs", "ys", color = "green", marker = ".")     #Plotting a scatter plot and taking the color of the marker as green and the marker or indicator as "."

# %% [markdown]
# **57.** Columns in your DataFrame can also be used to modify colors and sizes.  Bill has been keeping track of his performance at work over time, as well as how good he was feeling that day, and whether he had a cup of coffee in the morning.  Make a plot which incorporates all four features of this DataFrame.
#
# (Hint:  If you're having trouble seeing the plot, try multiplying the Series which you choose to represent size by 10 or more)
#
# *The chart doesn't have to be pretty: this isn't a course in data viz!*
#
# ```
# df = pd.DataFrame({"productivity":[5,2,3,1,4,5,6,7,8,3,4,8,9],
#                    "hours_in"    :[1,9,6,5,3,9,2,9,1,7,4,2,2],
#                    "happiness"   :[2,1,3,2,3,1,2,3,1,2,2,1,3],
#                    "caffienated" :[0,0,1,1,0,0,0,0,1,1,0,1,0]})
# ```

# %%
df = pd.DataFrame({"productivity":[5,2,3,1,4,5,6,7,8,3,4,8,9],
                   "hours_in"    :[1,9,6,5,3,9,2,9,1,7,4,2,2],
                   "happiness"   :[2,1,3,2,3,1,2,3,1,2,2,1,3],
                   "caffienated" :[0,0,1,1,0,0,0,0,1,1,0,1,0]})

df.plot.scatter("hours_in", "productivity", s = df.happiness * 10, c = df.caffienated ,marker="x")      #here taking all four columns and considering "hours_in" is taken on x axis and "productivity" is taken on y axis.

# %% [markdown]
# **58.**  What if we want to plot multiple things?  Pandas allows you to pass in a matplotlib *Axis* object for plots, and plots will also return an Axis object.
#
# Make a bar plot of monthly revenue with a line plot of monthly advertising spending (numbers in millions)
#
# ```
# df = pd.DataFrame({"revenue":[57,68,63,71,72,90,80,62,59,51,47,52],
#                    "advertising":[2.1,1.9,2.7,3.0,3.6,3.2,2.7,2.4,1.8,1.6,1.3,1.9],
#                    "month":range(12)
#                   })
# ```

# %%
df = pd.DataFrame({"revenue":[57,68,63,71,72,90,80,62,59,51,47,52],
                   "advertising":[2.1,1.9,2.7,3.0,3.6,3.2,2.7,2.4,1.8,1.6,1.3,1.9],
                   "month":range(12)
                  })
df
# Out:
#     revenue  advertising  month
# 0        57          2.1      0
# 1        68          1.9      1
# 2        63          2.7      2
# 3        71          3.0      3
# 4        72          3.6      4
# 5        90          3.2      5
# 6        80          2.7      6
# 7        62          2.4      7
# 8        59          1.8      8
# 9        51          1.6      9
# 10       47          1.3     10
# 11       52          1.9     11

# %%
ax = df.plot.bar("month", "revenue", color = "green")
df.plot.line("month", "advertising", secondary_y = True,ax=ax)
a.set_xlim((-1,12))
# Out:
# (-1.0, 12.0)

# %% [markdown]
# Now we're finally ready to create a candlestick chart, which is a very common tool used to analyze stock price data.  A candlestick chart shows the opening, closing, highest, and lowest price for a stock during a time window.  The color of the "candle" (the thick part of the bar) is green if the stock closed above its opening price, or red if below.
#
# ![Candlestick Example](img/candle.jpg)
#
# This was initially designed to be a pandas plotting challenge, but it just so happens that this type of plot is just not feasible using pandas' methods.  If you are unfamiliar with matplotlib, we have provided a function that will plot the chart for you so long as you can use pandas to get the data into the correct format.
#
# Your first step should be to get the data in the correct format using pandas' time-series grouping function.  We would like each candle to represent an hour's worth of data.  You can write your own aggregation function which returns the open/high/low/close, but pandas has a built-in which also does this.

# %% [markdown]
# The below cell contains helper functions.  Call ```day_stock_data()``` to generate a DataFrame containing the prices a hypothetical stock sold for, and the time the sale occurred.  Call ```plot_candlestick(df)``` on your properly aggregated and formatted stock data to print the candlestick chart.

# %%
import numpy as np
def float_to_time(x):
    return str(int(x)) + ":" + str(int(x%1 * 60)).zfill(2) + ":" + str(int(x*60 % 1 * 60)).zfill(2)

def day_stock_data():
    #NYSE is open from 9:30 to 4:00
    time = 9.5
    price = 100
    results = [(float_to_time(time), price)]
    while time < 16:
        elapsed = np.random.exponential(.001)
        time += elapsed
        if time > 16:
            break
        price_diff = np.random.uniform(.999, 1.001)
        price *= price_diff
        results.append((float_to_time(time), price))
    
    
    df = pd.DataFrame(results, columns = ['time','price'])
    df.time = pd.to_datetime(df.time)
    return df

#Don't read me unless you get stuck!
def plot_candlestick(agg):
    """
    agg is a DataFrame which has a DatetimeIndex and five columns: ["open","high","low","close","color"]
    """
    fig, ax = plt.subplots()
    for time in agg.index:
        ax.plot([time.hour] * 2, agg.loc[time, ["high","low"]].values, color = "black")
        ax.plot([time.hour] * 2, agg.loc[time, ["open","close"]].values, color = agg.loc[time, "color"], linewidth = 10)

    ax.set_xlim((8,16))
    ax.set_ylabel("Price")
    ax.set_xlabel("Hour")
    ax.set_title("OHLC of Stock Value During Trading Day")
    plt.show()

# %% [markdown]
# **59.** Generate a day's worth of random stock data, and aggregate / reformat it so that it has hourly summaries of the opening, highest, lowest, and closing prices

# %%
df = day_stock_data()
df.head()
# Out:
#                  time       price
# 0 2022-12-07 09:30:00  100.000000
# 1 2022-12-07 09:30:07   99.998837
# 2 2022-12-07 09:30:13  100.065895
# 3 2022-12-07 09:30:16  100.154469
# 4 2022-12-07 09:30:16  100.208410

# %%
df.set_index("time", inplace = True)
a = df.resample("H").ohlc()
a.columns = a.columns.droplevel()
a["color"] = (a.close > a.open).map({True:"green",False:"red"})
a.head()
# Out:
#                            open        high         low       close  color
# time
# 2022-12-07 09:00:00  100.000000  101.797324   99.998837  100.884958  green
# 2022-12-07 10:00:00  100.952864  102.114029   98.920171  100.729502    red
# 2022-12-07 11:00:00  100.725451  103.137042  100.725451  102.038550  green
# 2022-12-07 12:00:00  102.106858  103.585246  101.589698  102.036941    red
# 2022-12-07 13:00:00  102.073916  102.384852   99.191525   99.289254    red

# %% [markdown]
# **60.** Now that you have your properly-formatted data, try to plot it yourself as a candlestick chart.  Use the ```plot_candlestick(df)``` function above, or matplotlib's [```plot``` documentation](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.plot.html) if you get stuck.

# %%
plot_candlestick(a)
